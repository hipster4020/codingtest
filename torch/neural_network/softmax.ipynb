# %% [markdown]
# ### *시그모이드 함수처럼 신경망 유닛의 춮력을 0과 1 사이로 압축*
# ### *모든* 출력 합으로 각 출력을 나누어 k개 클래스에 대한 이산 확률 분포를 만듦
# ### *소프트맥스 출력 합 : 1*
# <br>
#
# # *이진 분류 : Sigmoid*
# # *다중 분류 : Softmax*
# ![image.png](attachment:image.png)

# %%
import torch
import torch.nn as nn

# %%
softmax = nn.Softmax(dim=1)
x_input = torch.randn(1, 3)
y_output = softmax(x_input)

# %%
print(x_input)
print(y_output)
print(torch.sum(y_output, dim=1))
# Out:
# tensor([[-2.1042, -1.5918,  0.2072]])
# tensor([[0.0784, 0.1308, 0.7908]])
# tensor([1.])
