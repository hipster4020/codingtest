# %% [markdown]
# # *희소 표현(Sparse Representation)*

# %% [markdown]
# 벡터 또는 행렬(matrix)의 값이 대부분 0으로 표현되는 방법<br>
# ex) One-hot Encoding)<br><br><br>
# <big><b>단점</b></big><br>
# <blockquote>단어 개수가 늘어나면 벡터의 차원이 한없이 커짐<br>
# 이러한 벡터는 공간적 낭비를 일으킴<br>
# 단어 벡터간 유사도를 표현할 수 없음</blockquote>

# %%
 import torch

# %%
dog = torch.Tensor([1, 0, 0, 0, 0])
cat = torch.Tensor([0, 1, 0, 0, 0])
computer = torch.Tensor([0, 0, 1, 0, 0])
netbook = torch.Tensor([0, 0, 0, 1, 0])
book = torch.Tensor([0, 0, 0, 0, 1])

# %%
print(torch.cosine_similarity(dog, cat, dim=0))
print(torch.cosine_similarity(cat, computer, dim=0))
print(torch.cosine_similarity(computer, netbook, dim=0))
print(torch.cosine_similarity(netbook, book, dim=0))
# Out:
# tensor(0.)
# tensor(0.)
# tensor(0.)
# tensor(0.)

# %% [markdown]
# #

# %% [markdown]
# # *밀집 표현(Dense Representation)*

# %% [markdown]
# 사용자가 설정한 값으로 모든 단어의 벡터 표현 차원을 맞추는 실수로 표현함<br>
# 벡터 차원을 단어 집합의 크기로 상정하지 않음<br><br>
# 사용자가 밀집 표현의 차원을 128로 설정한다면, 모든 단어의 벡터 표현의 차원은 128로 바뀌면서 모든 값이 실수가 됨<br>
# ex) 강아지 = [0.2 1.8 1.1 -2.1 1.1 2.8 ... ] # 이 벡터의 차원은 128

# %% [markdown]
# #

# %% [markdown]
# # *워드 임베딩(Word Embedding)*

# %% [markdown]
# <u>단어를 밀집 벡터(dense vector) 형태로 표현하는 방법</u><br>
# ex) LSA, Word2Vec, FastText, Glove 등<br>
# ![image.png](attachment:image.png)
