# %% [markdown]
# # 큐
# ![image.png](attachment:809bdd51-cfca-4641-ad1a-e9eba2369cb6.png)
# ![image.png](attachment:506602aa-07cb-4983-bea8-365d870df099.png)

# %%
import sys 

n = int(sys.stdin.readline())

queue = []

for i in range(n):
    x = sys.stdin.readline().split()
    
    if x[0] == 'push':
        queue.insert(0, x[1])
    elif x[0] == 'pop':
        if len(queue) == 0:
            print(-1)
        else:
            print(queue.pop())
    elif x[0] == 'size':
        print(len(queue))
    elif x[0] == 'empty':
        if len(queue) == 0:
            print(1)
        else:
            print(0)
    elif x[0] == 'front':
        if len(queue) == 0:
            print(-1)
        else:
            print(queue[-1])
    elif x[0] == 'back':
        if len(queue) == 0:
            print(-1)
        else:
            print(queue[0])
# Out:
#  15
#  push 1
#  push 2
#  front
# 1
#  back
# 2
#  size
# 2
#  empty
# 0
#  pop
# 1
#  pop
# 2
#  pop
# -1
#  size
# 0
#  empty
# 1
#  pop
# -1
#  push 3
#  empty
# 0
#  front
# 3

# %% [markdown]
# #

# %% [markdown]
# # 수 찾기
# ![image.png](attachment:051e587a-083e-445b-9731-fcbe62c84350.png)

# %%
# 시간 초과
# import sys
# n = int(sys.stdin.readline())

# a = sys.stdin.readline().split()

# m = int(sys.stdin.readline())
# ms = sys.stdin.readline().split()
# mss = []

# for i in ms:
#     mss.insert(0, i)

# for i in range(m):
#     if mss.pop() in a:
#         print(1)
#     else:
#         print(0)

# %%
N = int(input())
A = set(map(int, input().split()))

M = int(input())
arr = list(map(int, input().split()))

for num in arr:
    print(1) if num in A else print(0)
# Out:
#  5
#  4 1 5 2 3
#  5
#  1 3 7 9 5
# [1, 3, 7, 9, 5]
# 1
# 1
# 0
# 0
# 1

# %% [markdown]
# #
