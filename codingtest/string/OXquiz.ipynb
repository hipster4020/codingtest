# %% [markdown]
# # OX 퀴즈
# ![image.png](attachment:image.png)

# %%
n = int(input())

for _ in range(n):
    ox = input()
    
    score = 0
    temp_score = 0
    for i in range(len(ox)):
        if ox[i] == 'O':
            temp_score += 1
            score += temp_score
        else:
            temp_score = 0
    print(score)
# Out:
# 5
# OOXXOXXOOO
# 10
# OOXXOOXXOO
# 9
# OXOXOXOXOXOXOX
# 7
# OOOOOOOOOO
# 55
# OOOOXOOOOXOOOOX
# 30
