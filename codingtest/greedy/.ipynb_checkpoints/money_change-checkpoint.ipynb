# %% [markdown]
# # *거스름돈*

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #

# %% [markdown]
# ##### 임의의 가격

# %%
n = 1260
count = 0

# %%
coin_types = [500, 100, 50, 10]

for coin in coin_types:
    count += n // coin
    n %= coin
print(f"count : {count}")
# Out:
# count : 6
