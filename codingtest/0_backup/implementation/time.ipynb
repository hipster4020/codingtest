# %% [markdown]
# # *시각*

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# #

# %% [markdown]
# ### H 입력

# %%
h = int(input())
# Out:
# 2

# %% [markdown]
# ### 3포함 체크

# %%
count = 0

for i in range(h +1):
    for j in range(60):
        for k in range(60):
            if '3' in str(i) + str(j) + str(k):
                count += 1
print(count)
# Out:
# 4725
