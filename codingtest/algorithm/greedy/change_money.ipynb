# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 동전 500, 100, 50, 10
n = 5420

# %%
def main(n):
    count = 0
    coin_types = [500, 100, 50, 10]
    
    for coin in coin_types:
        count += n // coin
        n %= coin

    return count

# %%
result = main(n)

# %%
result
# Out:
# 16
